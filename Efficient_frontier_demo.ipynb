# %% [markdown]
# <a href="https://colab.research.google.com/github/JacquesYL/jacquesyl.github.io/blob/master/Efficient_frontier_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import key librares and modules
import pandas as pd
import numpy as np

# Import datetime module that comes pre-installed in Python
# datetime offers classes that work with date & time information
import datetime as dta

import matplotlib.pyplot as plt

# !pip install seaborn
import seaborn as sns

import plotly.express as px

# %%
# Define a function that performs interactive data visualization using Plotly Express
def plot_financial_data(df, title):

    fig = px.line(title = title)

    # For loop that plots all stock prices in the pandas dataframe df
    # Note that index starts with 1 because we want to skip the date column

    #skip the date, so the column starts with index = 1 (date is when index = 0)
    for i in df.columns[1:]:
        fig.add_scatter(x = df['Date'], y = df[i], name = i)
        fig.update_traces(line_width = 1)
        fig.update_layout({'plot_bgcolor': "white"})

    fig.show()

# %%
# Function to scale stock prices based on their initial starting price
# The objective of this function is to set all prices to start at a value of 1
def price_scaling(raw_prices_df):
    scaled_prices_df = raw_prices_df.copy()
    for i in raw_prices_df.columns[1:]:
          scaled_prices_df[i] = raw_prices_df[i]/raw_prices_df[i][0]
    return scaled_prices_df

# %%
import random

def generate_portfolio_weights(n):
    weights = []
    for i in range(n):
        weights.append(random.random())

    # let's make the sum of all weights add up to 1
    weights = weights/np.sum(weights)
    return weights

# %%
# Assume that we have $1,000,000 that we would like to invest in one or more of the selected stocks
# Let's create a function that receives the following arguments:
      # (1) Stocks closing prices
      # (2) Random weights
      # (3) Initial investment amount
# The function will return a DataFrame that contains the following:
      # (1) Daily value (position) of each individual stock over the specified time period
      # (2) Total daily value of the portfolio
      # (3) Percentage daily return

def asset_allocation(df, weights, initial_investment):
    portfolio_df = df.copy()

    # Scale stock prices using the "price_scaling" function that we defined earlier (Make them all start at 1)
    scaled_df = price_scaling(df)

    for i, stock in enumerate(scaled_df.columns[1:]):
        portfolio_df[stock] = scaled_df[stock] * weights[i] * initial_investment

    # Sum up all values and place the result in a new column titled "portfolio value [$]"
    # Note that we excluded the date column from this calculation
    portfolio_df['Portfolio Value [$]'] = portfolio_df[portfolio_df != 'Date'].sum(axis = 1, numeric_only = True)

    # Calculate the portfolio percentage daily return and replace NaNs with zeros
    portfolio_df['Portfolio Daily Return [%]'] = portfolio_df['Portfolio Value [$]'].pct_change(1) * 100
    portfolio_df.replace(np.nan, 0, inplace = True)

    return portfolio_df

# %%
# Let's define the simulation engine function
# The function receives:
    # (1) portfolio weights
    # (2) initial investment amount
# The function performs asset allocation and calculates portfolio statistical metrics including Sharpe ratio
# The function returns:
    # (1) Expected portfolio return
    # (2) Expected volatility
    # (3) Sharpe ratio
    # (4) Return on investment
    # (5) Final portfolio value in dollars


def simulation_engine(weights, initial_investment):
    # Perform asset allocation using the random weights (sent as arguments to the function)
    portfolio_df = asset_allocation(close_price_df, weights, initial_investment)

    # Calculate the return on the investment
    # Return on investment is calculated using the last final value of the portfolio compared to its initial value
    return_on_investment = ((portfolio_df['Portfolio Value [$]'][-1:] - portfolio_df['Portfolio Value [$]'][0])/
                             portfolio_df['Portfolio Value [$]'][0]) * 100

    # Daily change of every stock in the portfolio (Note that we dropped the date, portfolio daily worth and daily % returns)
    portfolio_daily_return_df = portfolio_df.drop(columns = ['Date', 'Portfolio Value [$]', 'Portfolio Daily Return [%]'])
    portfolio_daily_return_df = portfolio_daily_return_df.pct_change(1)

    # Portfolio Expected Return formula
    expected_portfolio_return = np.sum(weights * portfolio_daily_return_df.mean() ) * 252

    # Portfolio volatility (risk) formula
    # The risk of an asset is measured using the standard deviation which indicates the dispertion away from the mean
    # The risk of a portfolio is not a simple sum of the risks of the individual assets within the portfolio
    # Portfolio risk must consider correlations between assets within the portfolio which is indicated by the covariance
    # The covariance determines the relationship between the movements of two random variables
    # When two stocks move together, they have a positive covariance when they move inversely, the have a negative covariance

    covariance = portfolio_daily_return_df.cov() * 252
    expected_volatility = np.sqrt(np.dot(weights.T, np.dot(covariance, weights)))

    # Check out the chart for the 10-years U.S. treasury at https://ycharts.com/indicators/10_year_treasury_rate
    rf = 0.0425 # Try to set the risk free rate of return to 1% (assumption)

    # Calculate Sharpe ratio
    sharpe_ratio = (expected_portfolio_return - rf)/expected_volatility
    return expected_portfolio_return, expected_volatility, sharpe_ratio, portfolio_df['Portfolio Value [$]'][-1:].values[0], return_on_investment.values[0]

# %%
# Let's read multiple stocks data contained in "stock_prices.csv" attached in the course package
# The Appendix includes details on how to obtain this data using yfinance and Pandas Datareader
# Note that yfinance and Pandas Datareader might experience outage in some geographical regions

# We will focus our analysis on U.S. stocks, similar analysis could be performed on Asian, European or African stocks
# AMZN: Amazon Inc. - Multinational tech company focusing on e-commerce, cloud computing, and artificial intelligence
# JPM: JPMorgan Chase and Co. - Multinational investment bank and financial services holding company
# META: Meta Platforms, formerly named Facebook Inc. - META owns Facebook, Instagram, and WhatsApp
# PG: Procter and Gamble (P&G) - Multinational consumer goods corporation
# GOOG: Google (Alphabet Inc.) - Multinational company that focuses on search engine tech, e-commerce, Cloud and AI
# CAT: Caterpillar - World's largest construction-equipment manufacturer
# PFE: Pfizer Inc. - Multinational pharmaceutical and biotechnology corporation
# EXC: Exelon - An American Fortune 100 energy company
# DE: Deere & Company (John Deere) - Manufactures agricultural machinery and heavy equipment
# JNJ: Johnson & Johnson - A multinational corporation that develops medical devices and pharmaceuticals

close_price_df = pd.read_csv('stock_prices.csv')
close_price_df
# Out:
#             Date       AMZN         CAT          DE        EXC      GOOGL  \
# 0       1/2/2014  19.898500   69.512543   75.620926  14.121004  27.855856
# 1       1/3/2014  19.822001   69.473892   75.956062  13.835152  27.652653
# 2       1/6/2014  19.681499   68.561180   75.327690  13.923512  27.960960
# 3       1/7/2014  19.901501   68.785461   75.662811  13.996271  28.500000
# 4       1/8/2014  20.096001   68.947906   74.850121  13.965082  28.559309
# ...          ...        ...         ...         ...        ...        ...
# 2252  12/12/2022  90.550003  233.059998  437.049988  42.500000  93.309998
# 2253  12/13/2022  92.489998  235.490005  437.190002  42.540001  95.629997
# 2254  12/14/2022  91.580002  234.479996  438.440002  42.820000  95.070000
# 2255  12/15/2022  88.449997  230.660004  429.790008  42.380001  90.860001
# 2256  12/16/2022  87.860001  232.720001  431.089996  41.930000  90.260002
#
#              JNJ         JPM        META        PFE          PG
# 0      71.443314   45.640057   54.709999  20.879053   61.941517
# 1      72.086861   45.992889   54.560001  20.920183   61.872295
# 2      72.463608   46.259468   57.200001  20.940746   62.018425
# 3      74.001869   45.726311   57.919998  21.070980   62.618301
# 4      73.899841   46.157543   58.230000  21.214928   61.710812
# ...          ...         ...         ...        ...         ...
# 2252  177.839996  134.210007  114.709999  52.160000  152.470001
# 2253  179.210007  134.080002  120.150002  53.070000  152.240005
# 2254  179.759995  133.410004  121.589996  54.480000  152.839996
# 2255  177.490005  130.100006  116.150002  53.610001  151.110001
# 2256  175.669998  129.289993  119.430000  51.400002  150.440002
#
# [2257 rows x 11 columns]

# %%
# The objective of this code cell is to calculate the percentage daily return
# We will perform this calculation on all stocks except for the first column which is "Date"
daily_returns_df = close_price_df.iloc[:, 1:].pct_change() * 100
daily_returns_df.replace(np.nan, 0, inplace = True)
daily_returns_df
# Out:
#           AMZN       CAT        DE       EXC     GOOGL       JNJ       JPM  \
# 0     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    -0.384451 -0.055602  0.443179 -2.024307 -0.729481  0.900780  0.773077
# 2    -0.708814 -1.313748 -0.827284  0.638662  1.114930  0.522629  0.579608
# 3     1.117807  0.327126  0.444884  0.522567  1.927829  2.122805 -1.152537
# 4     0.977313  0.236162 -1.074095 -0.222838  0.208102 -0.137872  0.943073
# ...        ...       ...       ...       ...       ...       ...       ...
# 2252  1.638800  2.538609  0.515165  2.607441  0.517070  1.194942  1.551152
# 2253  2.142457  1.042653  0.032036  0.094120  2.486336  0.770361 -0.096867
# 2254 -0.983886 -0.428897  0.285917  0.658201 -0.585588  0.306896 -0.499700
# 2255 -3.417782 -1.629133 -1.972903 -1.027554 -4.428315 -1.262789 -2.481072
# 2256 -0.667039  0.893088  0.302470 -1.061823 -0.660355 -1.025414 -0.622608
#
#           META       PFE        PG
# 0     0.000000  0.000000  0.000000
# 1    -0.274169  0.196992 -0.111753
# 2     4.838708  0.098293  0.236179
# 3     1.258737  0.621916  0.967255
# 4     0.535223  0.683156 -1.449240
# ...        ...       ...       ...
# 2252 -1.026749  0.850732  1.027036
# 2253  4.742396  1.744632 -0.150847
# 2254  1.198498  2.656868  0.394108
# 2255 -4.474048 -1.596914 -1.131900
# 2256  2.823933 -4.122363 -0.443384
#
# [2257 rows x 10 columns]

# %%
# Let's test out the "simulation_engine" function and print out statistical metrics
# Define the initial investment amount
weights = np.ones(10)/10
initial_investment = 1000000
portfolio_metrics = simulation_engine(weights, initial_investment)

print('Expected Portfolio Annual Return = {:.2f}%'.format(portfolio_metrics[0] * 100))
print('Portfolio Standard Deviation (Volatility) = {:.2f}%'.format(portfolio_metrics[1] * 100))
print('Sharpe Ratio = {:.2f}'.format(portfolio_metrics[2]))
print('Portfolio Final Value = ${:.2f}'.format(portfolio_metrics[3]))
print('Return on Investment = {:.2f}%'.format(portfolio_metrics[4]))
# Out:
# Expected Portfolio Annual Return = 16.30%
# Portfolio Standard Deviation (Volatility) = 18.02%
# Sharpe Ratio = 0.74
# Portfolio Final Value = $3203874.76
# Return on Investment = 220.39%

# %%
# Let's test out the "simulation_engine" function and print out statistical metrics
# Define the initial investment amount
initial_investment = 1000000
portfolio_metrics = simulation_engine(weights, initial_investment)

# %%
# Set the number of simulation runs
sim_runs = 10000
initial_investment = 1000000

# Placeholder to store all weights
n = 10
weights_runs = np.zeros((sim_runs, n))

# Placeholder to store all Sharpe ratios
sharpe_ratio_runs = np.zeros(sim_runs)

# Placeholder to store all expected returns
expected_portfolio_returns_runs = np.zeros(sim_runs)

# Placeholder to store all volatility values
volatility_runs = np.zeros(sim_runs)

# Placeholder to store all returns on investment
return_on_investment_runs = np.zeros(sim_runs)

# Placeholder to store all final portfolio values
final_value_runs = np.zeros(sim_runs)

for i in range(sim_runs):
    # Generate random weights
    weights = generate_portfolio_weights(n)
    # Store the weights
    weights_runs[i,:] = weights

    # Call "simulation_engine" function and store Sharpe ratio, return and volatility
    # Note that asset allocation is performed using the "asset_allocation" function
    expected_portfolio_returns_runs[i], volatility_runs[i], sharpe_ratio_runs[i], final_value_runs[i], return_on_investment_runs[i] = simulation_engine(weights, initial_investment)
    print("Simulation Run = {}".format(i))
    print("Weights = {}, Final Value = ${:.2f}, Sharpe Ratio = {:.2f}".format(weights_runs[i].round(3), final_value_runs[i], sharpe_ratio_runs[i]))
    print('\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# Simulation Run = 2232
# Weights = [0.096 0.095 0.107 0.112 0.034 0.11  0.066 0.125 0.185 0.071], Final Value = $3150024.25, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2233
# Weights = [0.008 0.166 0.171 0.044 0.179 0.183 0.04  0.068 0.01  0.132], Final Value = $3331821.54, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2234
# Weights = [0.132 0.028 0.161 0.126 0.044 0.101 0.025 0.087 0.138 0.159], Final Value = $3343890.19, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2235
# Weights = [0.155 0.059 0.13  0.152 0.105 0.096 0.032 0.095 0.096 0.081], Final Value = $3379311.05, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2236
# Weights = [0.022 0.03  0.087 0.073 0.178 0.145 0.145 0.067 0.13  0.125], Final Value = $3017656.49, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2237
# Weights = [0.117 0.004 0.047 0.105 0.099 0.192 0.172 0.13  0.017 0.117], Final Value = $2999007.41, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2238
# Weights = [0.034 0.012 0.183 0.173 0.104 0.157 0.056 0.073 0.152 0.056], Final Value = $3297697.04, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2239
# Weights = [0.045 0.158 0.136 0.047 0.182 0.025 0.095 0.124 0.009 0.179], Final Value = $3291026.89, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2240
# Weights = [0.012 0.186 0.151 0.079 0.003 0.027 0.097 0.186 0.129 0.13 ], Final Value = $3162152.11, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2241
# Weights = [0.115 0.154 0.064 0.146 0.094 0.006 0.008 0.097 0.154 0.163], Final Value = $3147442.68, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2242
# Weights = [0.098 0.021 0.168 0.156 0.145 0.062 0.119 0.009 0.106 0.116], Final Value = $3445792.10, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2243
# Weights = [0.121 0.05  0.068 0.106 0.118 0.086 0.15  0.133 0.027 0.142], Final Value = $3121167.79, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2244
# Weights = [0.19  0.187 0.137 0.139 0.028 0.061 0.043 0.09  0.067 0.057], Final Value = $3523747.13, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2245
# Weights = [0.072 0.129 0.081 0.154 0.156 0.098 0.091 0.07  0.041 0.108], Final Value = $3187554.17, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2246
# Weights = [0.077 0.073 0.049 0.154 0.134 0.128 0.075 0.145 0.121 0.044], Final Value = $3004814.91, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2247
# Weights = [0.188 0.134 0.23  0.008 0.024 0.083 0.002 0.153 0.153 0.026], Final Value = $3671443.78, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2248
# Weights = [0.064 0.081 0.092 0.032 0.163 0.076 0.079 0.129 0.112 0.171], Final Value = $3087525.86, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2249
# Weights = [0.046 0.116 0.013 0.174 0.035 0.072 0.05  0.225 0.119 0.149], Final Value = $2763826.78, Sharpe Ratio = 0.59
#
#
# Simulation Run = 2250
# Weights = [0.126 0.047 0.15  0.132 0.022 0.016 0.226 0.115 0.136 0.03 ], Final Value = $3371287.67, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2251
# Weights = [0.122 0.214 0.095 0.028 0.213 0.006 0.046 0.022 0.173 0.082], Final Value = $3386226.81, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2252
# Weights = [0.123 0.179 0.167 0.11  0.037 0.114 0.072 0.029 0.076 0.093], Final Value = $3502317.31, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2253
# Weights = [0.218 0.108 0.053 0.153 0.123 0.132 0.012 0.033 0.101 0.067], Final Value = $3320580.23, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2254
# Weights = [0.074 0.113 0.082 0.158 0.163 0.083 0.106 0.145 0.042 0.034], Final Value = $3178115.43, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2255
# Weights = [0.201 0.075 0.194 0.082 0.086 0.175 0.111 0.042 0.019 0.015], Final Value = $3686197.87, Sharpe Ratio = 0.72
#
#
# Simulation Run = 2256
# Weights = [0.198 0.025 0.081 0.206 0.07  0.027 0.179 0.064 0.091 0.058], Final Value = $3340275.19, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2257
# Weights = [0.121 0.096 0.105 0.07  0.07  0.061 0.125 0.133 0.119 0.099], Final Value = $3221772.15, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2258
# Weights = [0.138 0.173 0.135 0.104 0.036 0.02  0.082 0.011 0.166 0.133], Final Value = $3427670.02, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2259
# Weights = [0.236 0.026 0.029 0.155 0.203 0.204 0.035 0.002 0.104 0.005], Final Value = $3289680.36, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2260
# Weights = [0.123 0.109 0.009 0.162 0.014 0.029 0.107 0.141 0.134 0.173], Final Value = $2912419.95, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2261
# Weights = [0.063 0.018 0.134 0.159 0.061 0.072 0.117 0.148 0.109 0.119], Final Value = $3160101.92, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2262
# Weights = [0.142 0.109 0.108 0.114 0.113 0.102 0.052 0.04  0.044 0.177], Final Value = $3331412.08, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2263
# Weights = [0.185 0.16  0.08  0.115 0.093 0.024 0.012 0.101 0.057 0.172], Final Value = $3326610.74, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2264
# Weights = [0.04  0.047 0.137 0.111 0.116 0.112 0.005 0.149 0.107 0.176], Final Value = $3125189.23, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2265
# Weights = [0.087 0.027 0.04  0.185 0.1   0.136 0.026 0.152 0.185 0.062], Final Value = $2919632.40, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2266
# Weights = [0.056 0.208 0.165 0.16  0.016 0.075 0.073 0.056 0.143 0.049], Final Value = $3391308.37, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2267
# Weights = [0.024 0.093 0.116 0.004 0.123 0.14  0.13  0.165 0.121 0.083], Final Value = $3064683.15, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2268
# Weights = [0.098 0.008 0.09  0.107 0.199 0.113 0.115 0.04  0.173 0.056], Final Value = $3190503.70, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2269
# Weights = [0.148 0.188 0.086 0.032 0.131 0.212 0.041 0.114 0.006 0.043], Final Value = $3296171.14, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2270
# Weights = [0.054 0.082 0.1   0.038 0.004 0.242 0.173 0.052 0.065 0.189], Final Value = $3031194.47, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2271
# Weights = [0.026 0.158 0.113 0.048 0.124 0.068 0.14  0.036 0.14  0.148], Final Value = $3176200.48, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2272
# Weights = [0.152 0.169 0.033 0.175 0.137 0.008 0.018 0.085 0.13  0.093], Final Value = $3190214.77, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2273
# Weights = [0.014 0.024 0.156 0.122 0.13  0.1   0.086 0.204 0.027 0.137], Final Value = $3149081.20, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2274
# Weights = [0.069 0.156 0.101 0.07  0.076 0.043 0.174 0.152 0.02  0.139], Final Value = $3174069.27, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2275
# Weights = [0.033 0.019 0.196 0.203 0.161 0.056 0.18  0.032 0.001 0.118], Final Value = $3461561.94, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2276
# Weights = [0.101 0.103 0.208 0.003 0.03  0.107 0.147 0.003 0.072 0.223], Final Value = $3497593.19, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2277
# Weights = [0.05  0.109 0.167 0.086 0.014 0.111 0.06  0.119 0.199 0.084], Final Value = $3237641.96, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2278
# Weights = [0.138 0.026 0.136 0.151 0.052 0.116 0.167 0.033 0.156 0.025], Final Value = $3364331.89, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2279
# Weights = [0.092 0.166 0.038 0.018 0.135 0.101 0.141 0.093 0.133 0.083], Final Value = $3047742.76, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2280
# Weights = [0.079 0.01  0.086 0.203 0.076 0.012 0.136 0.173 0.126 0.1  ], Final Value = $3064439.59, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2281
# Weights = [0.084 0.112 0.035 0.119 0.146 0.034 0.16  0.057 0.122 0.129], Final Value = $3053222.46, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2282
# Weights = [0.116 0.045 0.136 0.091 0.088 0.161 0.008 0.165 0.133 0.057], Final Value = $3238084.14, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2283
# Weights = [0.105 0.113 0.13  0.122 0.112 0.13  0.082 0.097 0.086 0.024], Final Value = $3338278.88, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2284
# Weights = [0.01  0.033 0.115 0.247 0.231 0.098 0.019 0.03  0.089 0.129], Final Value = $3181703.74, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2285
# Weights = [0.003 0.144 0.216 0.16  0.099 0.022 0.084 0.083 0.119 0.07 ], Final Value = $3459917.62, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2286
# Weights = [0.188 0.076 0.14  0.077 0.018 0.019 0.033 0.137 0.28  0.031], Final Value = $3376976.39, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2287
# Weights = [0.031 0.166 0.197 0.047 0.129 0.019 0.097 0.034 0.053 0.226], Final Value = $3452892.01, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2288
# Weights = [0.056 0.039 0.199 0.006 0.014 0.117 0.097 0.131 0.139 0.2  ], Final Value = $3259977.28, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2289
# Weights = [0.023 0.037 0.007 0.11  0.032 0.186 0.028 0.179 0.186 0.214], Final Value = $2594806.04, Sharpe Ratio = 0.57
#
#
# Simulation Run = 2290
# Weights = [0.126 0.064 0.139 0.064 0.184 0.105 0.12  0.145 0.046 0.007], Final Value = $3394898.94, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2291
# Weights = [0.161 0.104 0.168 0.024 0.055 0.063 0.029 0.162 0.135 0.1  ], Final Value = $3427996.27, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2292
# Weights = [0.066 0.17  0.149 0.141 0.089 0.058 0.1   0.018 0.145 0.064], Final Value = $3393398.94, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2293
# Weights = [0.102 0.016 0.145 0.01  0.086 0.173 0.207 0.061 0.052 0.149], Final Value = $3270492.73, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2294
# Weights = [0.025 0.147 0.025 0.026 0.165 0.018 0.181 0.101 0.178 0.133], Final Value = $2898256.73, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2295
# Weights = [0.151 0.155 0.04  0.077 0.104 0.091 0.016 0.081 0.122 0.163], Final Value = $3121855.47, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2296
# Weights = [0.188 0.031 0.002 0.048 0.128 0.07  0.147 0.097 0.191 0.098], Final Value = $3011616.11, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2297
# Weights = [0.044 0.02  0.058 0.053 0.195 0.161 0.099 0.167 0.035 0.168], Final Value = $2915965.48, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2298
# Weights = [0.071 0.045 0.156 0.294 0.061 0.006 0.091 0.152 0.069 0.054], Final Value = $3330844.76, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2299
# Weights = [0.139 0.018 0.172 0.048 0.213 0.131 0.122 0.058 0.081 0.018], Final Value = $3526522.28, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2300
# Weights = [0.107 0.106 0.164 0.188 0.1   0.062 0.103 0.163 0.001 0.007], Final Value = $3460424.89, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2301
# Weights = [0.015 0.159 0.15  0.194 0.06  0.016 0.088 0.019 0.098 0.2  ], Final Value = $3283602.78, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2302
# Weights = [0.116 0.096 0.138 0.059 0.112 0.134 0.132 0.014 0.082 0.115], Final Value = $3379770.24, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2303
# Weights = [0.06  0.066 0.023 0.144 0.088 0.105 0.019 0.15  0.154 0.191], Final Value = $2812631.09, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2304
# Weights = [0.033 0.151 0.192 0.021 0.    0.106 0.096 0.054 0.159 0.188], Final Value = $3305861.33, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2305
# Weights = [0.077 0.045 0.069 0.109 0.148 0.113 0.183 0.114 0.001 0.141], Final Value = $3077935.96, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2306
# Weights = [0.14  0.187 0.047 0.044 0.126 0.21  0.092 0.009 0.105 0.039], Final Value = $3203531.85, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2307
# Weights = [0.097 0.091 0.127 0.187 0.032 0.13  0.062 0.127 0.039 0.107], Final Value = $3247747.25, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2308
# Weights = [0.144 0.075 0.107 0.055 0.146 0.102 0.096 0.141 0.039 0.095], Final Value = $3290479.15, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2309
# Weights = [0.025 0.078 0.214 0.022 0.14  0.092 0.033 0.203 0.105 0.088], Final Value = $3346565.45, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2310
# Weights = [0.166 0.168 0.065 0.063 0.109 0.132 0.014 0.227 0.044 0.01 ], Final Value = $3204212.08, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2311
# Weights = [0.189 0.19  0.05  0.027 0.028 0.019 0.161 0.113 0.115 0.109], Final Value = $3219483.67, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2312
# Weights = [0.048 0.206 0.188 0.009 0.002 0.158 0.005 0.126 0.091 0.168], Final Value = $3311577.28, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2313
# Weights = [0.145 0.041 0.057 0.06  0.144 0.051 0.035 0.049 0.211 0.207], Final Value = $3100264.64, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2314
# Weights = [0.118 0.115 0.113 0.153 0.116 0.003 0.001 0.088 0.163 0.13 ], Final Value = $3299686.38, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2315
# Weights = [0.069 0.034 0.016 0.16  0.027 0.117 0.216 0.097 0.219 0.046], Final Value = $2830065.59, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2316
# Weights = [0.123 0.178 0.166 0.183 0.038 0.004 0.036 0.153 0.076 0.045], Final Value = $3488125.86, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2317
# Weights = [0.022 0.02  0.075 0.178 0.003 0.121 0.138 0.062 0.171 0.211], Final Value = $2883204.70, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2318
# Weights = [0.044 0.225 0.118 0.132 0.032 0.183 0.029 0.075 0.001 0.161], Final Value = $3206262.67, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2319
# Weights = [0.007 0.06  0.035 0.166 0.088 0.145 0.15  0.096 0.09  0.162], Final Value = $2817855.99, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2320
# Weights = [0.117 0.175 0.028 0.082 0.153 0.185 0.127 0.02  0.091 0.02 ], Final Value = $3137636.91, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2321
# Weights = [0.069 0.045 0.11  0.137 0.177 0.076 0.011 0.101 0.148 0.126], Final Value = $3172344.63, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2322
# Weights = [0.09  0.084 0.028 0.088 0.078 0.183 0.064 0.125 0.09  0.169], Final Value = $2890194.58, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2323
# Weights = [0.089 0.038 0.022 0.167 0.117 0.103 0.163 0.095 0.062 0.145], Final Value = $2945878.10, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2324
# Weights = [0.026 0.036 0.079 0.196 0.088 0.068 0.11  0.213 0.105 0.078], Final Value = $2947668.00, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2325
# Weights = [0.078 0.169 0.166 0.025 0.015 0.143 0.058 0.112 0.12  0.115], Final Value = $3310952.35, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2326
# Weights = [0.067 0.113 0.128 0.052 0.092 0.211 0.138 0.033 0.037 0.13 ], Final Value = $3241424.20, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2327
# Weights = [0.122 0.068 0.036 0.138 0.217 0.081 0.213 0.008 0.086 0.031], Final Value = $3191462.50, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2328
# Weights = [0.154 0.002 0.017 0.051 0.219 0.049 0.164 0.084 0.139 0.12 ], Final Value = $3048503.99, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2329
# Weights = [0.012 0.104 0.127 0.096 0.141 0.226 0.013 0.052 0.141 0.089], Final Value = $3133842.29, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2330
# Weights = [0.018 0.123 0.118 0.113 0.094 0.155 0.098 0.039 0.114 0.128], Final Value = $3139372.82, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2331
# Weights = [0.144 0.177 0.034 0.164 0.065 0.065 0.082 0.132 0.08  0.059], Final Value = $3135416.97, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2332
# Weights = [0.143 0.012 0.122 0.079 0.167 0.011 0.047 0.118 0.187 0.114], Final Value = $3297521.91, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2333
# Weights = [0.164 0.138 0.119 0.007 0.043 0.084 0.048 0.065 0.243 0.089], Final Value = $3323980.51, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2334
# Weights = [0.089 0.092 0.166 0.093 0.062 0.048 0.    0.184 0.141 0.124], Final Value = $3294529.09, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2335
# Weights = [0.006 0.133 0.122 0.127 0.066 0.104 0.105 0.127 0.079 0.131], Final Value = $3101580.71, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2336
# Weights = [0.022 0.065 0.099 0.025 0.134 0.125 0.026 0.177 0.159 0.167], Final Value = $2957079.15, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2337
# Weights = [0.134 0.105 0.    0.131 0.093 0.178 0.156 0.084 0.034 0.084], Final Value = $2988840.80, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2338
# Weights = [0.045 0.2   0.068 0.062 0.045 0.126 0.093 0.181 0.072 0.109], Final Value = $2993040.31, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2339
# Weights = [0.034 0.087 0.145 0.037 0.083 0.165 0.018 0.192 0.159 0.081], Final Value = $3108215.33, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2340
# Weights = [0.041 0.124 0.166 0.017 0.095 0.125 0.144 0.141 0.092 0.055], Final Value = $3285061.96, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2341
# Weights = [0.035 0.069 0.111 0.097 0.114 0.145 0.069 0.077 0.138 0.146], Final Value = $3086121.96, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2342
# Weights = [0.056 0.08  0.154 0.18  0.142 0.094 0.028 0.154 0.011 0.1  ], Final Value = $3307551.51, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2343
# Weights = [0.041 0.205 0.049 0.062 0.072 0.109 0.003 0.228 0.095 0.135], Final Value = $2902971.76, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2344
# Weights = [0.135 0.263 0.016 0.055 0.042 0.009 0.002 0.154 0.166 0.158], Final Value = $3023754.11, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2345
# Weights = [0.158 0.153 0.188 0.023 0.127 0.145 0.109 0.019 0.074 0.004], Final Value = $3660035.52, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2346
# Weights = [0.137 0.099 0.087 0.182 0.055 0.051 0.104 0.131 0.123 0.03 ], Final Value = $3236140.05, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2347
# Weights = [0.1   0.167 0.017 0.126 0.011 0.159 0.117 0.149 0.031 0.122], Final Value = $2929204.05, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2348
# Weights = [0.096 0.061 0.108 0.039 0.091 0.113 0.142 0.162 0.123 0.065], Final Value = $3148179.54, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2349
# Weights = [0.117 0.026 0.003 0.115 0.011 0.222 0.213 0.054 0.026 0.214], Final Value = $2845565.43, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2350
# Weights = [0.09  0.113 0.148 0.009 0.001 0.179 0.091 0.093 0.15  0.125], Final Value = $3226319.44, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2351
# Weights = [0.102 0.126 0.102 0.145 0.091 0.109 0.067 0.089 0.084 0.084], Final Value = $3245823.88, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2352
# Weights = [0.084 0.027 0.126 0.16  0.119 0.017 0.108 0.064 0.157 0.138], Final Value = $3248245.76, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2353
# Weights = [0.201 0.084 0.16  0.044 0.089 0.023 0.057 0.014 0.181 0.147], Final Value = $3550466.75, Sharpe Ratio = 0.72
#
#
# Simulation Run = 2354
# Weights = [0.026 0.094 0.177 0.04  0.087 0.03  0.159 0.172 0.066 0.149], Final Value = $3263136.21, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2355
# Weights = [0.059 0.059 0.206 0.131 0.191 0.206 0.05  0.009 0.06  0.028], Final Value = $3526383.83, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2356
# Weights = [0.08  0.191 0.058 0.093 0.112 0.162 0.006 0.118 0.004 0.177], Final Value = $3071957.23, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2357
# Weights = [0.14  0.064 0.134 0.242 0.002 0.082 0.032 0.079 0.044 0.181], Final Value = $3334309.36, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2358
# Weights = [0.079 0.044 0.026 0.126 0.122 0.105 0.148 0.088 0.121 0.14 ], Final Value = $2924738.54, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2359
# Weights = [0.114 0.188 0.015 0.171 0.128 0.176 0.122 0.047 0.022 0.017], Final Value = $3117811.71, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2360
# Weights = [0.06  0.183 0.051 0.079 0.122 0.045 0.127 0.113 0.194 0.027], Final Value = $3055273.39, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2361
# Weights = [0.188 0.113 0.058 0.024 0.006 0.135 0.04  0.184 0.158 0.094], Final Value = $3094617.07, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2362
# Weights = [0.199 0.013 0.008 0.143 0.143 0.14  0.132 0.066 0.009 0.146], Final Value = $3099010.75, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2363
# Weights = [0.064 0.044 0.154 0.205 0.157 0.037 0.008 0.166 0.034 0.131], Final Value = $3303475.03, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2364
# Weights = [0.113 0.134 0.027 0.126 0.139 0.037 0.07  0.202 0.133 0.019], Final Value = $3029420.78, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2365
# Weights = [0.101 0.119 0.089 0.104 0.107 0.091 0.085 0.121 0.02  0.163], Final Value = $3181512.35, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2366
# Weights = [0.198 0.093 0.161 0.18  0.04  0.011 0.075 0.023 0.089 0.131], Final Value = $3590668.10, Sharpe Ratio = 0.73
#
#
# Simulation Run = 2367
# Weights = [0.203 0.068 0.009 0.191 0.009 0.095 0.137 0.094 0.013 0.18 ], Final Value = $3070898.22, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2368
# Weights = [0.189 0.088 0.022 0.18  0.061 0.136 0.085 0.04  0.024 0.176], Final Value = $3131814.56, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2369
# Weights = [0.009 0.19  0.156 0.096 0.028 0.047 0.168 0.174 0.025 0.108], Final Value = $3232944.87, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2370
# Weights = [0.061 0.223 0.068 0.014 0.097 0.119 0.216 0.018 0.153 0.031], Final Value = $3155501.68, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2371
# Weights = [0.093 0.112 0.089 0.126 0.09  0.136 0.054 0.115 0.154 0.031], Final Value = $3152735.73, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2372
# Weights = [0.113 0.033 0.096 0.116 0.069 0.014 0.086 0.164 0.139 0.17 ], Final Value = $3114904.42, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2373
# Weights = [0.143 0.049 0.118 0.095 0.078 0.123 0.093 0.099 0.084 0.118], Final Value = $3278497.25, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2374
# Weights = [0.031 0.206 0.035 0.003 0.102 0.152 0.034 0.141 0.108 0.188], Final Value = $2866077.87, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2375
# Weights = [0.133 0.062 0.167 0.066 0.088 0.143 0.067 0.067 0.053 0.155], Final Value = $3418370.01, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2376
# Weights = [0.052 0.125 0.128 0.15  0.061 0.118 0.129 0.102 0.054 0.081], Final Value = $3227159.99, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2377
# Weights = [0.001 0.175 0.165 0.185 0.031 0.017 0.191 0.039 0.066 0.13 ], Final Value = $3325673.57, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2378
# Weights = [0.119 0.095 0.018 0.105 0.138 0.088 0.107 0.112 0.092 0.125], Final Value = $3002735.12, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2379
# Weights = [0.212 0.069 0.075 0.001 0.1   0.029 0.152 0.13  0.026 0.207], Final Value = $3271400.76, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2380
# Weights = [0.146 0.105 0.212 0.176 0.015 0.048 0.079 0.017 0.077 0.126], Final Value = $3647397.10, Sharpe Ratio = 0.73
#
#
# Simulation Run = 2381
# Weights = [0.108 0.02  0.193 0.21  0.098 0.026 0.2   0.008 0.047 0.091], Final Value = $3565668.80, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2382
# Weights = [0.131 0.14  0.131 0.001 0.099 0.132 0.01  0.11  0.125 0.121], Final Value = $3311253.76, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2383
# Weights = [0.151 0.068 0.044 0.105 0.085 0.093 0.141 0.028 0.141 0.143], Final Value = $3120782.96, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2384
# Weights = [0.175 0.05  0.159 0.078 0.09  0.115 0.092 0.18  0.059 0.001], Final Value = $3456832.75, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2385
# Weights = [0.083 0.08  0.039 0.114 0.061 0.114 0.13  0.016 0.148 0.215], Final Value = $2964142.01, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2386
# Weights = [0.028 0.044 0.15  0.154 0.001 0.09  0.116 0.155 0.158 0.105], Final Value = $3116445.57, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2387
# Weights = [0.126 0.166 0.106 0.076 0.018 0.062 0.154 0.148 0.134 0.011], Final Value = $3264071.70, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2388
# Weights = [0.171 0.152 0.018 0.081 0.054 0.075 0.031 0.154 0.147 0.117], Final Value = $3036949.05, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2389
# Weights = [0.05  0.008 0.107 0.158 0.171 0.198 0.074 0.189 0.001 0.044], Final Value = $3099986.21, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2390
# Weights = [0.13  0.14  0.205 0.135 0.07  0.108 0.023 0.081 0.07  0.038], Final Value = $3609341.64, Sharpe Ratio = 0.72
#
#
# Simulation Run = 2391
# Weights = [0.118 0.136 0.153 0.164 0.165 0.076 0.002 0.061 0.089 0.036], Final Value = $3502961.97, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2392
# Weights = [0.183 0.092 0.189 0.129 0.003 0.217 0.029 0.004 0.061 0.091], Final Value = $3587610.08, Sharpe Ratio = 0.74
#
#
# Simulation Run = 2393
# Weights = [0.2   0.273 0.323 0.017 0.003 0.032 0.061 0.038 0.023 0.031], Final Value = $4161515.02, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2394
# Weights = [0.084 0.016 0.146 0.145 0.012 0.219 0.059 0.052 0.166 0.102], Final Value = $3198440.78, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2395
# Weights = [0.221 0.061 0.023 0.261 0.024 0.115 0.125 0.075 0.028 0.069], Final Value = $3194831.02, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2396
# Weights = [0.021 0.121 0.065 0.072 0.132 0.091 0.153 0.058 0.127 0.159], Final Value = $2995749.19, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2397
# Weights = [0.139 0.177 0.151 0.087 0.04  0.051 0.136 0.007 0.001 0.211], Final Value = $3497400.98, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2398
# Weights = [0.12  0.068 0.107 0.152 0.071 0.132 0.004 0.085 0.146 0.116], Final Value = $3209051.30, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2399
# Weights = [0.206 0.006 0.008 0.196 0.108 0.112 0.001 0.099 0.141 0.124], Final Value = $3047439.67, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2400
# Weights = [0.103 0.07  0.135 0.131 0.149 0.067 0.04  0.154 0.143 0.008], Final Value = $3315629.77, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2401
# Weights = [0.139 0.013 0.034 0.115 0.204 0.191 0.034 0.168 0.055 0.046], Final Value = $3035862.79, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2402
# Weights = [0.053 0.179 0.087 0.014 0.082 0.059 0.202 0.078 0.092 0.155], Final Value = $3123458.47, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2403
# Weights = [0.154 0.173 0.152 0.033 0.036 0.03  0.129 0.1   0.071 0.123], Final Value = $3468071.25, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2404
# Weights = [0.18  0.107 0.017 0.006 0.109 0.057 0.124 0.181 0.138 0.081], Final Value = $3042749.97, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2405
# Weights = [0.117 0.047 0.012 0.105 0.157 0.143 0.09  0.167 0.075 0.086], Final Value = $2930306.19, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2406
# Weights = [0.05  0.154 0.088 0.115 0.03  0.089 0.234 0.005 0.084 0.151], Final Value = $3144311.75, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2407
# Weights = [0.044 0.012 0.156 0.11  0.149 0.029 0.117 0.098 0.129 0.154], Final Value = $3248941.90, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2408
# Weights = [0.054 0.016 0.15  0.16  0.131 0.151 0.115 0.134 0.055 0.034], Final Value = $3253313.91, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2409
# Weights = [0.044 0.142 0.114 0.155 0.056 0.09  0.097 0.203 0.042 0.057], Final Value = $3141549.24, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2410
# Weights = [0.159 0.009 0.089 0.118 0.061 0.082 0.118 0.188 0.16  0.017], Final Value = $3165936.20, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2411
# Weights = [0.071 0.005 0.136 0.072 0.104 0.042 0.117 0.127 0.166 0.16 ], Final Value = $3167546.39, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2412
# Weights = [0.019 0.087 0.104 0.202 0.203 0.146 0.008 0.01  0.172 0.048], Final Value = $3172596.89, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2413
# Weights = [0.027 0.174 0.155 0.062 0.136 0.022 0.12  0.017 0.1   0.186], Final Value = $3342527.44, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2414
# Weights = [0.153 0.18  0.043 0.    0.119 0.071 0.011 0.193 0.098 0.131], Final Value = $3097509.46, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2415
# Weights = [0.126 0.046 0.145 0.128 0.128 0.055 0.083 0.046 0.123 0.119], Final Value = $3397199.14, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2416
# Weights = [0.192 0.065 0.098 0.026 0.007 0.069 0.274 0.192 0.023 0.054], Final Value = $3277020.85, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2417
# Weights = [0.092 0.085 0.119 0.132 0.105 0.117 0.141 0.112 0.057 0.042], Final Value = $3268175.90, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2418
# Weights = [0.164 0.13  0.036 0.052 0.164 0.141 0.111 0.011 0.153 0.038], Final Value = $3205050.96, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2419
# Weights = [0.204 0.004 0.152 0.059 0.041 0.068 0.134 0.156 0.15  0.032], Final Value = $3422680.55, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2420
# Weights = [0.015 0.004 0.082 0.01  0.193 0.159 0.08  0.107 0.18  0.17 ], Final Value = $2907318.26, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2421
# Weights = [0.15  0.16  0.14  0.018 0.078 0.017 0.107 0.059 0.137 0.135], Final Value = $3436712.38, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2422
# Weights = [0.028 0.158 0.069 0.045 0.03  0.027 0.185 0.188 0.188 0.082], Final Value = $2939697.54, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2423
# Weights = [0.204 0.138 0.2   0.084 0.009 0.024 0.07  0.036 0.063 0.172], Final Value = $3690204.57, Sharpe Ratio = 0.73
#
#
# Simulation Run = 2424
# Weights = [0.092 0.012 0.021 0.158 0.143 0.013 0.184 0.119 0.13  0.127], Final Value = $2944147.62, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2425
# Weights = [0.048 0.122 0.112 0.146 0.164 0.167 0.001 0.092 0.073 0.076], Final Value = $3199521.49, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2426
# Weights = [0.098 0.003 0.097 0.039 0.053 0.107 0.174 0.065 0.185 0.18 ], Final Value = $3069947.98, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2427
# Weights = [0.296 0.042 0.047 0.193 0.253 0.049 0.035 0.024 0.013 0.048], Final Value = $3530544.07, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2428
# Weights = [0.119 0.023 0.129 0.136 0.11  0.072 0.094 0.118 0.108 0.092], Final Value = $3284671.37, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2429
# Weights = [0.136 0.135 0.175 0.138 0.102 0.049 0.067 0.03  0.023 0.145], Final Value = $3573333.13, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2430
# Weights = [0.16  0.038 0.139 0.143 0.171 0.067 0.004 0.038 0.12  0.12 ], Final Value = $3451969.22, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2431
# Weights = [0.036 0.198 0.027 0.102 0.149 0.083 0.117 0.078 0.069 0.14 ], Final Value = $2979497.49, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2432
# Weights = [0.016 0.084 0.108 0.16  0.162 0.145 0.128 0.063 0.123 0.01 ], Final Value = $3154990.27, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2433
# Weights = [0.107 0.11  0.162 0.028 0.173 0.058 0.087 0.057 0.108 0.11 ], Final Value = $3455708.66, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2434
# Weights = [0.162 0.194 0.139 0.105 0.069 0.08  0.027 0.013 0.104 0.107], Final Value = $3509463.07, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2435
# Weights = [0.085 0.138 0.054 0.15  0.007 0.161 0.094 0.048 0.157 0.106], Final Value = $3024218.96, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2436
# Weights = [0.114 0.124 0.105 0.114 0.047 0.166 0.086 0.092 0.134 0.018], Final Value = $3232987.25, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2437
# Weights = [0.069 0.152 0.011 0.15  0.054 0.094 0.055 0.057 0.182 0.176], Final Value = $2882434.94, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2438
# Weights = [0.187 0.    0.025 0.099 0.02  0.219 0.086 0.228 0.069 0.066], Final Value = $2941336.62, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2439
# Weights = [0.012 0.022 0.096 0.153 0.116 0.163 0.007 0.117 0.149 0.164], Final Value = $2949107.87, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2440
# Weights = [0.129 0.014 0.153 0.027 0.009 0.15  0.053 0.115 0.168 0.182], Final Value = $3224505.18, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2441
# Weights = [0.12  0.059 0.092 0.118 0.108 0.14  0.077 0.105 0.078 0.104], Final Value = $3184593.57, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2442
# Weights = [0.156 0.103 0.048 0.078 0.055 0.132 0.102 0.128 0.138 0.061], Final Value = $3093026.20, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2443
# Weights = [0.139 0.141 0.05  0.111 0.1   0.149 0.143 0.061 0.037 0.067], Final Value = $3189169.34, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2444
# Weights = [0.135 0.078 0.093 0.084 0.097 0.143 0.141 0.054 0.025 0.149], Final Value = $3246519.88, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2445
# Weights = [0.181 0.023 0.074 0.021 0.131 0.039 0.197 0.19  0.104 0.039], Final Value = $3207874.48, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2446
# Weights = [0.152 0.127 0.112 0.153 0.029 0.037 0.091 0.057 0.089 0.154], Final Value = $3344840.47, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2447
# Weights = [0.011 0.04  0.144 0.192 0.034 0.004 0.159 0.133 0.157 0.125], Final Value = $3127768.08, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2448
# Weights = [0.13  0.118 0.028 0.097 0.14  0.063 0.081 0.118 0.137 0.087], Final Value = $3064445.49, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2449
# Weights = [0.04  0.112 0.208 0.027 0.092 0.148 0.149 0.045 0.13  0.048], Final Value = $3439513.47, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2450
# Weights = [0.062 0.129 0.138 0.076 0.15  0.111 0.027 0.146 0.014 0.148], Final Value = $3262106.79, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2451
# Weights = [0.112 0.063 0.168 0.023 0.141 0.065 0.078 0.149 0.14  0.061], Final Value = $3385967.01, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2452
# Weights = [0.039 0.088 0.008 0.188 0.15  0.209 0.022 0.03  0.187 0.08 ], Final Value = $2849950.95, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2453
# Weights = [0.173 0.116 0.124 0.137 0.031 0.064 0.039 0.021 0.081 0.213], Final Value = $3400061.12, Sharpe Ratio = 0.72
#
#
# Simulation Run = 2454
# Weights = [0.071 0.117 0.104 0.071 0.138 0.127 0.12  0.158 0.017 0.077], Final Value = $3182078.06, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2455
# Weights = [0.145 0.103 0.12  0.057 0.098 0.164 0.005 0.166 0.037 0.105], Final Value = $3279634.45, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2456
# Weights = [0.013 0.123 0.004 0.136 0.026 0.001 0.181 0.183 0.159 0.175], Final Value = $2708164.11, Sharpe Ratio = 0.58
#
#
# Simulation Run = 2457
# Weights = [0.008 0.022 0.039 0.126 0.05  0.145 0.128 0.185 0.107 0.19 ], Final Value = $2716472.01, Sharpe Ratio = 0.58
#
#
# Simulation Run = 2458
# Weights = [0.008 0.106 0.161 0.131 0.111 0.099 0.042 0.158 0.149 0.036], Final Value = $3215857.57, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2459
# Weights = [0.147 0.052 0.094 0.106 0.014 0.018 0.149 0.149 0.135 0.135], Final Value = $3175794.67, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2460
# Weights = [0.162 0.035 0.012 0.193 0.159 0.02  0.024 0.172 0.164 0.059], Final Value = $3026895.67, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2461
# Weights = [0.078 0.093 0.057 0.072 0.142 0.139 0.064 0.12  0.136 0.098], Final Value = $3015580.07, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2462
# Weights = [0.067 0.    0.041 0.052 0.102 0.063 0.267 0.113 0.059 0.236], Final Value = $2891548.04, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2463
# Weights = [0.186 0.08  0.163 0.1   0.035 0.004 0.166 0.101 0.057 0.106], Final Value = $3533967.33, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2464
# Weights = [0.127 0.024 0.048 0.12  0.008 0.181 0.228 0.095 0.072 0.099], Final Value = $3006904.55, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2465
# Weights = [0.12  0.177 0.094 0.088 0.173 0.065 0.001 0.05  0.19  0.041], Final Value = $3320754.72, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2466
# Weights = [0.147 0.1   0.158 0.091 0.066 0.006 0.148 0.012 0.128 0.144], Final Value = $3493411.35, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2467
# Weights = [0.131 0.178 0.03  0.087 0.032 0.097 0.162 0.047 0.132 0.103], Final Value = $3086692.11, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2468
# Weights = [0.13  0.149 0.052 0.044 0.19  0.022 0.063 0.16  0.066 0.123], Final Value = $3163271.50, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2469
# Weights = [0.171 0.168 0.007 0.005 0.035 0.142 0.131 0.115 0.025 0.2  ], Final Value = $3007686.28, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2470
# Weights = [0.008 0.112 0.144 0.14  0.139 0.035 0.063 0.159 0.114 0.087], Final Value = $3196210.56, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2471
# Weights = [0.105 0.139 0.092 0.165 0.074 0.171 0.043 0.059 0.041 0.11 ], Final Value = $3224809.25, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2472
# Weights = [0.081 0.157 0.071 0.242 0.137 0.055 0.06  0.036 0.099 0.062], Final Value = $3230267.19, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2473
# Weights = [0.014 0.01  0.147 0.143 0.012 0.141 0.173 0.076 0.137 0.146], Final Value = $3096209.98, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2474
# Weights = [0.123 0.096 0.147 0.035 0.034 0.097 0.088 0.08  0.177 0.123], Final Value = $3314016.99, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2475
# Weights = [0.031 0.164 0.042 0.044 0.203 0.036 0.159 0.066 0.212 0.043], Final Value = $3023480.54, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2476
# Weights = [0.114 0.113 0.025 0.018 0.052 0.167 0.17  0.144 0.132 0.065], Final Value = $2935056.94, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2477
# Weights = [0.153 0.026 0.048 0.104 0.06  0.118 0.13  0.149 0.065 0.147], Final Value = $3038959.98, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2478
# Weights = [0.043 0.19  0.041 0.014 0.194 0.085 0.211 0.034 0.04  0.148], Final Value = $3068015.01, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2479
# Weights = [0.085 0.126 0.141 0.137 0.098 0.123 0.119 0.099 0.011 0.06 ], Final Value = $3357190.29, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2480
# Weights = [0.147 0.137 0.19  0.036 0.016 0.174 0.229 0.025 0.004 0.041], Final Value = $3593488.27, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2481
# Weights = [0.146 0.101 0.146 0.202 0.005 0.055 0.124 0.139 0.073 0.008], Final Value = $3423938.25, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2482
# Weights = [0.178 0.109 0.129 0.056 0.15  0.08  0.108 0.009 0.084 0.097], Final Value = $3503706.45, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2483
# Weights = [0.186 0.006 0.188 0.077 0.139 0.026 0.153 0.086 0.128 0.013], Final Value = $3617297.42, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2484
# Weights = [0.024 0.133 0.123 0.14  0.006 0.121 0.084 0.163 0.109 0.096], Final Value = $3083895.94, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2485
# Weights = [0.15  0.068 0.21  0.076 0.171 0.    0.007 0.243 0.048 0.026], Final Value = $3600595.27, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2486
# Weights = [0.09  0.107 0.073 0.155 0.15  0.114 0.105 0.045 0.017 0.144], Final Value = $3186409.29, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2487
# Weights = [0.044 0.124 0.04  0.013 0.148 0.151 0.174 0.043 0.125 0.137], Final Value = $2958465.35, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2488
# Weights = [0.076 0.09  0.18  0.056 0.158 0.021 0.125 0.086 0.16  0.047], Final Value = $3445972.14, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2489
# Weights = [0.141 0.118 0.013 0.179 0.145 0.047 0.135 0.009 0.121 0.093], Final Value = $3131402.22, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2490
# Weights = [0.097 0.22  0.1   0.151 0.155 0.041 0.04  0.09  0.031 0.074], Final Value = $3356086.40, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2491
# Weights = [0.162 0.019 0.1   0.101 0.016 0.141 0.059 0.124 0.184 0.095], Final Value = $3164903.94, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2492
# Weights = [0.109 0.152 0.025 0.031 0.151 0.006 0.106 0.151 0.082 0.186], Final Value = $3014709.60, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2493
# Weights = [0.082 0.024 0.02  0.097 0.167 0.18  0.175 0.075 0.118 0.063], Final Value = $2929624.72, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2494
# Weights = [0.135 0.19  0.009 0.05  0.177 0.017 0.014 0.169 0.171 0.069], Final Value = $3042825.25, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2495
# Weights = [0.042 0.07  0.066 0.176 0.029 0.122 0.107 0.185 0.165 0.038], Final Value = $2916735.68, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2496
# Weights = [0.068 0.052 0.154 0.    0.071 0.064 0.029 0.228 0.148 0.185], Final Value = $3134806.43, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2497
# Weights = [0.192 0.058 0.117 0.044 0.032 0.193 0.075 0.017 0.093 0.177], Final Value = $3332433.10, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2498
# Weights = [0.026 0.143 0.201 0.055 0.049 0.028 0.204 0.033 0.173 0.088], Final Value = $3419732.94, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2499
# Weights = [0.206 0.002 0.1   0.09  0.167 0.033 0.111 0.155 0.1   0.035], Final Value = $3361874.05, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2500
# Weights = [0.112 0.111 0.146 0.054 0.148 0.104 0.073 0.123 0.016 0.114], Final Value = $3382593.44, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2501
# Weights = [0.078 0.129 0.046 0.009 0.108 0.    0.256 0.033 0.325 0.016], Final Value = $3051664.34, Sharpe Ratio = 0.60
#
#
# Simulation Run = 2502
# Weights = [0.124 0.151 0.069 0.142 0.102 0.035 0.158 0.113 0.005 0.1  ], Final Value = $3237297.66, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2503
# Weights = [0.076 0.192 0.07  0.004 0.172 0.074 0.011 0.093 0.136 0.173], Final Value = $3113714.32, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2504
# Weights = [0.206 0.132 0.018 0.102 0.174 0.023 0.139 0.067 0.03  0.108], Final Value = $3257224.39, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2505
# Weights = [0.05  0.097 0.169 0.193 0.031 0.089 0.154 0.036 0.168 0.012], Final Value = $3361496.28, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2506
# Weights = [0.019 0.144 0.061 0.177 0.095 0.103 0.163 0.101 0.091 0.045], Final Value = $3020061.08, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2507
# Weights = [0.076 0.115 0.031 0.206 0.208 0.019 0.075 0.229 0.005 0.036], Final Value = $3042518.96, Sharpe Ratio = 0.59
#
#
# Simulation Run = 2508
# Weights = [0.139 0.194 0.11  0.132 0.097 0.01  0.028 0.153 0.004 0.131], Final Value = $3368940.11, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2509
# Weights = [0.124 0.032 0.125 0.043 0.082 0.103 0.061 0.112 0.196 0.122], Final Value = $3209191.56, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2510
# Weights = [0.118 0.139 0.076 0.073 0.065 0.059 0.043 0.204 0.006 0.218], Final Value = $3099625.31, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2511
# Weights = [0.182 0.164 0.064 0.082 0.01  0.052 0.208 0.186 0.043 0.008], Final Value = $3246080.86, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2512
# Weights = [0.096 0.171 0.012 0.068 0.154 0.154 0.154 0.037 0.003 0.152], Final Value = $3033490.32, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2513
# Weights = [0.018 0.169 0.155 0.168 0.217 0.015 0.015 0.107 0.057 0.081], Final Value = $3374445.96, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2514
# Weights = [0.037 0.254 0.124 0.038 0.069 0.089 0.033 0.183 0.107 0.064], Final Value = $3194346.73, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2515
# Weights = [0.102 0.052 0.094 0.052 0.167 0.    0.145 0.057 0.173 0.158], Final Value = $3201605.44, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2516
# Weights = [0.144 0.123 0.116 0.096 0.058 0.01  0.131 0.071 0.117 0.135], Final Value = $3344049.54, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2517
# Weights = [0.101 0.164 0.012 0.087 0.014 0.092 0.069 0.128 0.164 0.17 ], Final Value = $2882182.99, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2518
# Weights = [0.127 0.087 0.133 0.133 0.097 0.065 0.133 0.133 0.05  0.042], Final Value = $3371148.17, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2519
# Weights = [0.109 0.07  0.177 0.059 0.01  0.066 0.125 0.068 0.178 0.138], Final Value = $3370799.40, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2520
# Weights = [0.115 0.084 0.01  0.042 0.058 0.168 0.097 0.158 0.17  0.1  ], Final Value = $2847006.02, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2521
# Weights = [0.14  0.105 0.184 0.007 0.134 0.188 0.153 0.03  0.012 0.046], Final Value = $3580573.85, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2522
# Weights = [0.153 0.004 0.126 0.055 0.026 0.076 0.199 0.06  0.199 0.102], Final Value = $3274079.72, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2523
# Weights = [0.081 0.051 0.13  0.113 0.047 0.136 0.074 0.15  0.071 0.15 ], Final Value = $3158615.33, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2524
# Weights = [0.076 0.005 0.108 0.224 0.031 0.079 0.175 0.206 0.024 0.072], Final Value = $3105325.87, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2525
# Weights = [0.194 0.028 0.052 0.002 0.096 0.112 0.048 0.138 0.135 0.193], Final Value = $3084028.05, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2526
# Weights = [0.145 0.    0.135 0.175 0.028 0.014 0.207 0.156 0.087 0.052], Final Value = $3324972.64, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2527
# Weights = [0.01  0.065 0.167 0.036 0.019 0.135 0.104 0.033 0.096 0.336], Final Value = $3130773.85, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2528
# Weights = [0.178 0.104 0.069 0.042 0.011 0.051 0.104 0.039 0.204 0.198], Final Value = $3176436.96, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2529
# Weights = [0.049 0.155 0.141 0.151 0.128 0.036 0.051 0.074 0.142 0.074], Final Value = $3324453.48, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2530
# Weights = [0.098 0.071 0.022 0.092 0.255 0.005 0.164 0.045 0.176 0.072], Final Value = $3077475.51, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2531
# Weights = [0.094 0.026 0.085 0.178 0.019 0.159 0.074 0.115 0.117 0.134], Final Value = $3039195.68, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2532
# Weights = [0.095 0.129 0.065 0.014 0.146 0.058 0.196 0.217 0.005 0.075], Final Value = $3100281.45, Sharpe Ratio = 0.59
#
#
# Simulation Run = 2533
# Weights = [0.019 0.2   0.07  0.051 0.222 0.095 0.168 0.022 0.004 0.149], Final Value = $3154278.54, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2534
# Weights = [0.145 0.13  0.172 0.029 0.173 0.063 0.043 0.089 0.06  0.097], Final Value = $3554772.30, Sharpe Ratio = 0.69
#
#
# Simulation Run = 2535
# Weights = [0.111 0.01  0.154 0.157 0.058 0.089 0.047 0.018 0.264 0.092], Final Value = $3319770.54, Sharpe Ratio = 0.70
#
#
# Simulation Run = 2536
# Weights = [0.098 0.145 0.059 0.057 0.021 0.07  0.115 0.151 0.151 0.133], Final Value = $3012743.98, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2537
# Weights = [0.117 0.155 0.13  0.037 0.032 0.158 0.024 0.196 0.06  0.091], Final Value = $3243007.70, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2538
# Weights = [0.069 0.018 0.136 0.029 0.188 0.149 0.058 0.149 0.137 0.067], Final Value = $3189590.04, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2539
# Weights = [0.154 0.149 0.028 0.044 0.022 0.184 0.064 0.105 0.125 0.123], Final Value = $3014582.25, Sharpe Ratio = 0.65
#
#
# Simulation Run = 2540
# Weights = [0.128 0.118 0.087 0.034 0.009 0.161 0.162 0.039 0.116 0.147], Final Value = $3164044.05, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2541
# Weights = [0.174 0.139 0.038 0.097 0.034 0.159 0.199 0.001 0.061 0.098], Final Value = $3194388.17, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2542
# Weights = [0.067 0.179 0.165 0.027 0.141 0.01  0.064 0.188 0.151 0.008], Final Value = $3379391.25, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2543
# Weights = [0.164 0.091 0.114 0.073 0.116 0.032 0.085 0.086 0.079 0.16 ], Final Value = $3363073.63, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2544
# Weights = [0.164 0.09  0.143 0.153 0.009 0.094 0.084 0.061 0.023 0.179], Final Value = $3418425.56, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2545
# Weights = [0.114 0.013 0.004 0.151 0.197 0.201 0.125 0.116 0.07  0.009], Final Value = $2951206.76, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2546
# Weights = [0.011 0.2   0.01  0.1   0.106 0.095 0.074 0.099 0.075 0.23 ], Final Value = $2817673.05, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2547
# Weights = [0.161 0.089 0.147 0.096 0.16  0.158 0.002 0.048 0.015 0.125], Final Value = $3488228.26, Sharpe Ratio = 0.71
#
#
# Simulation Run = 2548
# Weights = [0.028 0.136 0.179 0.076 0.16  0.166 0.084 0.078 0.053 0.039], Final Value = $3386835.13, Sharpe Ratio = 0.67
#
#
# Simulation Run = 2549
# Weights = [0.023 0.104 0.034 0.182 0.197 0.069 0.083 0.243 0.014 0.05 ], Final Value = $2914685.69, Sharpe Ratio = 0.57
#
#
# Simulation Run = 2550
# Weights = [0.08  0.037 0.124 0.116 0.155 0.109 0.151 0.087 0.021 0.121], Final Value = $3260059.52, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2551
# Weights = [0.136 0.152 0.032 0.082 0.061 0.09  0.107 0.114 0.047 0.177], Final Value = $3056505.97, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2552
# Weights = [0.232 0.072 0.159 0.113 0.072 0.01  0.017 0.052 0.224 0.049], Final Value = $3596575.87, Sharpe Ratio = 0.72
#
#
# Simulation Run = 2553
# Weights = [0.129 0.123 0.042 0.116 0.096 0.051 0.142 0.05  0.105 0.144], Final Value = $3127335.68, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2554
# Weights = [0.104 0.097 0.071 0.034 0.141 0.101 0.089 0.125 0.136 0.103], Final Value = $3102001.57, Sharpe Ratio = 0.64
#
#
# Simulation Run = 2555
# Weights = [0.01  0.154 0.05  0.021 0.203 0.208 0.042 0.077 0.114 0.121], Final Value = $2938868.23, Sharpe Ratio = 0.62
#
#
# Simulation Run = 2556
# Weights = [0.146 0.087 0.105 0.007 0.081 0.037 0.148 0.111 0.122 0.156], Final Value = $3249430.65, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2557
# Weights = [0.087 0.008 0.068 0.2   0.012 0.137 0.051 0.226 0.014 0.197], Final Value = $2918174.88, Sharpe Ratio = 0.61
#
#
# Simulation Run = 2558
# Weights = [0.2   0.08  0.215 0.051 0.014 0.124 0.157 0.042 0.104 0.012], Final Value = $3704136.10, Sharpe Ratio = 0.72
#
#
# Simulation Run = 2559
# Weights = [0.079 0.077 0.123 0.092 0.109 0.129 0.09  0.145 0.036 0.119], Final Value = $3204372.01, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2560
# Weights = [0.02  0.091 0.056 0.174 0.14  0.039 0.049 0.114 0.085 0.232], Final Value = $2938783.53, Sharpe Ratio = 0.63
#
#
# Simulation Run = 2561
# Weights = [0.177 0.035 0.078 0.148 0.071 0.073 0.142 0.073 0.068 0.136], Final Value = $3247625.82, Sharpe Ratio = 0.68
#
#
# Simulation Run = 2562
# Weights = [0.136 0.087 0.168 0.042 0.172 0.016 0.065 0.157 0.023 0.134], Final Value = $3478914.40, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2563
# Weights = [0.093 0.15  0.146 0.125 0.062 0.007 0.112 0.152 0.006 0.148], Final Value = $3354941.60, Sharpe Ratio = 0.66
#
#
# Simulation Run = 2564
# ...
#
#
# Simulation Run = 3371
# Weights = [0.089 0.165 0.149 0.002 0.097 0.154 0.076 0.033 0.074 0.16 ], Final Value = $3354409.06, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3372
# Weights = [0.108 0.007 0.188 0.055 0.102 0.05  0.033 0.095 0.178 0.185], Final Value = $3374916.33, Sharpe Ratio = 0.70
#
#
# Simulation Run = 3373
# Weights = [0.093 0.022 0.131 0.04  0.101 0.136 0.051 0.179 0.146 0.101], Final Value = $3150610.68, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3374
# Weights = [0.202 0.009 0.041 0.057 0.193 0.091 0.188 0.105 0.064 0.05 ], Final Value = $3216082.43, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3375
# Weights = [0.068 0.242 0.054 0.06  0.012 0.241 0.038 0.024 0.185 0.075], Final Value = $3030307.26, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3376
# Weights = [0.156 0.016 0.028 0.186 0.129 0.122 0.087 0.067 0.024 0.184], Final Value = $3073615.45, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3377
# Weights = [0.112 0.146 0.039 0.155 0.061 0.095 0.129 0.119 0.13  0.012], Final Value = $3077940.63, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3378
# Weights = [0.087 0.189 0.198 0.102 0.011 0.104 0.128 0.014 0.117 0.049], Final Value = $3543591.59, Sharpe Ratio = 0.69
#
#
# Simulation Run = 3379
# Weights = [0.049 0.173 0.041 0.013 0.17  0.141 0.048 0.055 0.146 0.164], Final Value = $2978214.56, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3380
# Weights = [0.116 0.161 0.116 0.072 0.054 0.034 0.11  0.038 0.156 0.145], Final Value = $3309860.56, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3381
# Weights = [0.037 0.102 0.07  0.005 0.069 0.114 0.159 0.135 0.136 0.173], Final Value = $2922718.24, Sharpe Ratio = 0.61
#
#
# Simulation Run = 3382
# Weights = [0.013 0.049 0.113 0.04  0.167 0.172 0.097 0.149 0.183 0.017], Final Value = $3040604.99, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3383
# Weights = [0.047 0.067 0.089 0.163 0.121 0.123 0.155 0.024 0.056 0.156], Final Value = $3122569.70, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3384
# Weights = [0.017 0.134 0.104 0.119 0.173 0.065 0.083 0.158 0.139 0.008], Final Value = $3131903.61, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3385
# Weights = [0.106 0.073 0.102 0.083 0.131 0.044 0.036 0.135 0.162 0.128], Final Value = $3180570.57, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3386
# Weights = [0.084 0.101 0.149 0.106 0.145 0.027 0.112 0.121 0.066 0.088], Final Value = $3370404.37, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3387
# Weights = [0.013 0.165 0.118 0.068 0.135 0.061 0.123 0.175 0.    0.142], Final Value = $3147046.30, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3388
# Weights = [0.005 0.146 0.143 0.031 0.119 0.074 0.118 0.086 0.149 0.128], Final Value = $3188947.41, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3389
# Weights = [0.138 0.022 0.13  0.126 0.078 0.07  0.143 0.111 0.057 0.124], Final Value = $3314511.39, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3390
# Weights = [0.084 0.095 0.178 0.112 0.014 0.005 0.077 0.202 0.008 0.224], Final Value = $3318757.63, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3391
# Weights = [0.164 0.111 0.011 0.192 0.14  0.048 0.068 0.023 0.128 0.115], Final Value = $3137865.16, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3392
# Weights = [0.177 0.041 0.041 0.153 0.137 0.172 0.033 0.161 0.077 0.008], Final Value = $3125833.22, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3393
# Weights = [0.173 0.049 0.074 0.133 0.063 0.201 0.11  0.011 0.028 0.158], Final Value = $3231764.56, Sharpe Ratio = 0.69
#
#
# Simulation Run = 3394
# Weights = [0.187 0.029 0.124 0.081 0.044 0.179 0.031 0.14  0.049 0.136], Final Value = $3297511.39, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3395
# Weights = [0.089 0.172 0.164 0.135 0.142 0.044 0.012 0.002 0.085 0.157], Final Value = $3495010.14, Sharpe Ratio = 0.71
#
#
# Simulation Run = 3396
# Weights = [0.177 0.112 0.088 0.006 0.091 0.03  0.093 0.171 0.082 0.151], Final Value = $3246945.94, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3397
# Weights = [0.181 0.007 0.085 0.035 0.107 0.149 0.155 0.006 0.116 0.16 ], Final Value = $3246795.26, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3398
# Weights = [0.012 0.038 0.173 0.111 0.066 0.046 0.171 0.055 0.164 0.164], Final Value = $3229585.43, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3399
# Weights = [0.153 0.075 0.038 0.156 0.071 0.15  0.138 0.111 0.089 0.02 ], Final Value = $3103814.83, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3400
# Weights = [0.137 0.114 0.096 0.049 0.106 0.137 0.014 0.157 0.175 0.016], Final Value = $3209861.63, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3401
# Weights = [0.058 0.013 0.115 0.107 0.058 0.184 0.029 0.109 0.185 0.143], Final Value = $3032142.21, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3402
# Weights = [0.15  0.064 0.147 0.072 0.104 0.096 0.152 0.114 0.037 0.064], Final Value = $3426239.44, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3403
# Weights = [0.153 0.032 0.063 0.022 0.139 0.152 0.128 0.147 0.158 0.006], Final Value = $3118602.72, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3404
# Weights = [0.271 0.268 0.071 0.012 0.119 0.044 0.126 0.032 0.049 0.007], Final Value = $3597001.52, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3405
# Weights = [0.097 0.169 0.062 0.174 0.04  0.069 0.169 0.1   0.003 0.117], Final Value = $3151329.24, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3406
# Weights = [0.086 0.071 0.129 0.141 0.113 0.048 0.029 0.125 0.111 0.146], Final Value = $3242248.99, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3407
# Weights = [0.009 0.137 0.07  0.095 0.113 0.074 0.145 0.146 0.159 0.052], Final Value = $2973397.02, Sharpe Ratio = 0.61
#
#
# Simulation Run = 3408
# Weights = [0.143 0.19  0.02  0.018 0.154 0.038 0.104 0.108 0.143 0.082], Final Value = $3109077.38, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3409
# Weights = [0.127 0.05  0.036 0.087 0.131 0.027 0.095 0.151 0.142 0.152], Final Value = $3007538.83, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3410
# Weights = [0.058 0.067 0.093 0.019 0.223 0.041 0.154 0.174 0.138 0.033], Final Value = $3126860.10, Sharpe Ratio = 0.60
#
#
# Simulation Run = 3411
# Weights = [0.139 0.076 0.076 0.158 0.116 0.155 0.028 0.145 0.043 0.063], Final Value = $3185619.38, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3412
# Weights = [0.124 0.143 0.064 0.084 0.17  0.122 0.036 0.125 0.129 0.004], Final Value = $3192391.41, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3413
# Weights = [0.155 0.183 0.045 0.094 0.119 0.058 0.107 0.078 0.145 0.016], Final Value = $3230859.96, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3414
# Weights = [0.089 0.14  0.169 0.149 0.144 0.017 0.193 0.066 0.03  0.003], Final Value = $3549485.62, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3415
# Weights = [0.134 0.115 0.018 0.132 0.081 0.182 0.133 0.019 0.141 0.044], Final Value = $3058447.59, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3416
# Weights = [0.146 0.12  0.142 0.086 0.116 0.087 0.127 0.087 0.029 0.059], Final Value = $3468532.08, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3417
# Weights = [0.015 0.139 0.016 0.069 0.039 0.114 0.068 0.104 0.185 0.249], Final Value = $2720973.70, Sharpe Ratio = 0.60
#
#
# Simulation Run = 3418
# Weights = [0.099 0.235 0.038 0.114 0.092 0.047 0.175 0.035 0.137 0.029], Final Value = $3169862.96, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3419
# Weights = [0.073 0.201 0.001 0.149 0.109 0.104 0.154 0.041 0.131 0.038], Final Value = $2989299.79, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3420
# Weights = [0.102 0.153 0.033 0.108 0.082 0.131 0.032 0.193 0.16  0.006], Final Value = $2979622.36, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3421
# Weights = [0.12  0.097 0.077 0.131 0.112 0.123 0.086 0.083 0.093 0.079], Final Value = $3191957.90, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3422
# Weights = [0.002 0.293 0.078 0.165 0.101 0.221 0.01  0.048 0.068 0.015], Final Value = $3128425.14, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3423
# Weights = [0.111 0.143 0.092 0.134 0.112 0.092 0.005 0.084 0.153 0.074], Final Value = $3234102.78, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3424
# Weights = [0.13  0.013 0.005 0.098 0.04  0.185 0.196 0.155 0.133 0.046], Final Value = $2850986.56, Sharpe Ratio = 0.60
#
#
# Simulation Run = 3425
# Weights = [0.046 0.137 0.198 0.111 0.082 0.138 0.147 0.074 0.032 0.036], Final Value = $3467112.83, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3426
# Weights = [0.03  0.13  0.054 0.103 0.114 0.116 0.182 0.154 0.111 0.006], Final Value = $2975810.85, Sharpe Ratio = 0.61
#
#
# Simulation Run = 3427
# Weights = [0.221 0.068 0.077 0.215 0.098 0.072 0.176 0.045 0.014 0.014], Final Value = $3439937.28, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3428
# Weights = [0.134 0.097 0.076 0.068 0.18  0.033 0.156 0.04  0.068 0.149], Final Value = $3272431.37, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3429
# Weights = [0.025 0.015 0.168 0.093 0.147 0.079 0.141 0.096 0.132 0.104], Final Value = $3250150.99, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3430
# Weights = [0.138 0.061 0.204 0.005 0.162 0.002 0.113 0.158 0.111 0.047], Final Value = $3569694.72, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3431
# Weights = [0.096 0.067 0.051 0.142 0.221 0.115 0.041 0.007 0.038 0.222], Final Value = $3125111.55, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3432
# Weights = [0.227 0.033 0.17  0.194 0.059 0.058 0.008 0.016 0.053 0.182], Final Value = $3623383.30, Sharpe Ratio = 0.74
#
#
# Simulation Run = 3433
# Weights = [0.036 0.055 0.089 0.121 0.081 0.214 0.097 0.208 0.075 0.025], Final Value = $2970071.33, Sharpe Ratio = 0.61
#
#
# Simulation Run = 3434
# Weights = [0.031 0.152 0.163 0.036 0.085 0.018 0.21  0.048 0.007 0.249], Final Value = $3326984.55, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3435
# Weights = [0.094 0.114 0.134 0.127 0.083 0.068 0.037 0.125 0.111 0.105], Final Value = $3286585.66, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3436
# Weights = [0.216 0.031 0.133 0.016 0.08  0.073 0.053 0.156 0.107 0.135], Final Value = $3385269.95, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3437
# Weights = [0.027 0.068 0.023 0.054 0.175 0.096 0.004 0.132 0.182 0.238], Final Value = $2771268.69, Sharpe Ratio = 0.59
#
#
# Simulation Run = 3438
# Weights = [0.131 0.112 0.009 0.184 0.075 0.147 0.019 0.111 0.122 0.091], Final Value = $2969323.45, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3439
# Weights = [0.117 0.009 0.105 0.082 0.151 0.21  0.035 0.165 0.019 0.107], Final Value = $3160445.46, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3440
# Weights = [0.116 0.135 0.136 0.065 0.157 0.022 0.088 0.024 0.097 0.159], Final Value = $3425346.13, Sharpe Ratio = 0.69
#
#
# Simulation Run = 3441
# Weights = [0.028 0.122 0.039 0.063 0.097 0.068 0.234 0.167 0.115 0.067], Final Value = $2894305.59, Sharpe Ratio = 0.59
#
#
# Simulation Run = 3442
# Weights = [0.022 0.17  0.025 0.016 0.154 0.071 0.155 0.112 0.16  0.115], Final Value = $2887866.73, Sharpe Ratio = 0.60
#
#
# Simulation Run = 3443
# Weights = [0.077 0.152 0.076 0.005 0.075 0.203 0.182 0.099 0.051 0.081], Final Value = $3089548.51, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3444
# Weights = [0.025 0.04  0.098 0.185 0.122 0.02  0.157 0.034 0.13  0.189], Final Value = $3095571.99, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3445
# Weights = [0.007 0.2   0.131 0.116 0.008 0.01  0.038 0.17  0.193 0.128], Final Value = $3102982.92, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3446
# Weights = [0.108 0.169 0.018 0.172 0.118 0.159 0.157 0.026 0.035 0.038], Final Value = $3108776.89, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3447
# Weights = [0.149 0.041 0.036 0.167 0.108 0.179 0.051 0.004 0.153 0.112], Final Value = $3087514.11, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3448
# Weights = [0.087 0.065 0.045 0.141 0.155 0.122 0.039 0.143 0.192 0.01 ], Final Value = $3002984.66, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3449
# Weights = [0.071 0.102 0.158 0.049 0.186 0.117 0.009 0.048 0.125 0.135], Final Value = $3356735.45, Sharpe Ratio = 0.69
#
#
# Simulation Run = 3450
# Weights = [0.18  0.202 0.097 0.048 0.106 0.012 0.055 0.041 0.151 0.108], Final Value = $3419856.53, Sharpe Ratio = 0.69
#
#
# Simulation Run = 3451
# Weights = [0.034 0.095 0.138 0.132 0.092 0.234 0.062 0.058 0.046 0.108], Final Value = $3202712.34, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3452
# Weights = [0.108 0.026 0.133 0.121 0.179 0.078 0.103 0.085 0.021 0.145], Final Value = $3337450.80, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3453
# Weights = [0.014 0.016 0.133 0.016 0.125 0.052 0.199 0.139 0.229 0.079], Final Value = $3070309.43, Sharpe Ratio = 0.61
#
#
# Simulation Run = 3454
# Weights = [0.103 0.058 0.116 0.134 0.116 0.074 0.035 0.117 0.126 0.121], Final Value = $3224455.34, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3455
# Weights = [0.152 0.122 0.07  0.015 0.066 0.149 0.15  0.155 0.079 0.044], Final Value = $3161881.31, Sharpe Ratio = 0.63
#
#
# Simulation Run = 3456
# Weights = [0.114 0.035 0.124 0.105 0.024 0.111 0.038 0.171 0.124 0.154], Final Value = $3149374.38, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3457
# Weights = [0.047 0.007 0.172 0.08  0.054 0.049 0.185 0.177 0.077 0.153], Final Value = $3212776.51, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3458
# Weights = [0.008 0.14  0.081 0.155 0.106 0.136 0.162 0.019 0.118 0.075], Final Value = $3076214.06, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3459
# Weights = [0.013 0.11  0.033 0.063 0.007 0.187 0.066 0.103 0.212 0.206], Final Value = $2717532.80, Sharpe Ratio = 0.60
#
#
# Simulation Run = 3460
# Weights = [0.091 0.051 0.058 0.182 0.199 0.223 0.012 0.031 0.138 0.016], Final Value = $3113036.59, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3461
# Weights = [0.093 0.068 0.202 0.039 0.148 0.183 0.149 0.026 0.01  0.083], Final Value = $3535638.53, Sharpe Ratio = 0.69
#
#
# Simulation Run = 3462
# Weights = [0.013 0.087 0.021 0.024 0.003 0.214 0.199 0.137 0.137 0.165], Final Value = $2676857.49, Sharpe Ratio = 0.57
#
#
# Simulation Run = 3463
# Weights = [0.045 0.052 0.141 0.146 0.122 0.127 0.063 0.152 0.009 0.143], Final Value = $3198848.26, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3464
# Weights = [0.065 0.071 0.075 0.016 0.091 0.196 0.164 0.121 0.147 0.054], Final Value = $2997610.11, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3465
# Weights = [0.17  0.201 0.124 0.124 0.08  0.035 0.045 0.015 0.024 0.183], Final Value = $3506060.08, Sharpe Ratio = 0.71
#
#
# Simulation Run = 3466
# Weights = [0.063 0.012 0.045 0.206 0.196 0.152 0.053 0.017 0.227 0.029], Final Value = $3011392.36, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3467
# Weights = [0.029 0.122 0.171 0.163 0.072 0.075 0.173 0.036 0.123 0.036], Final Value = $3372568.70, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3468
# Weights = [0.212 0.037 0.001 0.205 0.045 0.099 0.02  0.207 0.167 0.007], Final Value = $3000703.11, Sharpe Ratio = 0.61
#
#
# Simulation Run = 3469
# Weights = [0.002 0.01  0.028 0.056 0.229 0.013 0.167 0.172 0.193 0.129], Final Value = $2783168.06, Sharpe Ratio = 0.56
#
#
# Simulation Run = 3470
# Weights = [0.081 0.073 0.126 0.034 0.168 0.079 0.202 0.033 0.071 0.135], Final Value = $3299919.60, Sharpe Ratio = 0.66
#
#
# Simulation Run = 3471
# Weights = [0.111 0.184 0.011 0.071 0.131 0.068 0.023 0.154 0.077 0.17 ], Final Value = $2974583.07, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3472
# Weights = [0.119 0.024 0.014 0.254 0.144 0.046 0.129 0.028 0.064 0.177], Final Value = $3038207.19, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3473
# Weights = [0.134 0.123 0.093 0.118 0.049 0.126 0.121 0.103 0.13  0.003], Final Value = $3247099.86, Sharpe Ratio = 0.67
#
#
# Simulation Run = 3474
# Weights = [0.145 0.119 0.037 0.039 0.139 0.105 0.069 0.102 0.166 0.08 ], Final Value = $3091765.79, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3475
# Weights = [0.079 0.17  0.072 0.054 0.127 0.065 0.047 0.155 0.078 0.153], Final Value = $3095927.38, Sharpe Ratio = 0.64
#
#
# Simulation Run = 3476
# Weights = [0.082 0.025 0.243 0.082 0.129 0.024 0.183 0.052 0.08  0.102], Final Value = $3621136.18, Sharpe Ratio = 0.70
#
#
# Simulation Run = 3477
# Weights = [0.181 0.025 0.028 0.125 0.01  0.093 0.15  0.17  0.15  0.068], Final Value = $3003716.57, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3478
# Weights = [0.12  0.041 0.112 0.021 0.016 0.217 0.092 0.157 0.024 0.2  ], Final Value = $3102620.06, Sharpe Ratio = 0.65
#
#
# Simulation Run = 3479
# Weights = [0.017 0.066 0.098 0.138 0.08  0.046 0.182 0.152 0.047 0.173], Final Value = $3023904.32, Sharpe Ratio = 0.62
#
#
# Simulation Run = 3480
# Weights = [0.193 0.081 0.073 0.074 0.027 0.18  0.162 0.021 0.034 0.155], Final Value = $3253387.23, Sharpe Ratio = 0.68
#
#
# Simulation Run = 3481
# Weights = [0.083 0.065 0.153 0.123 0.153 0.093 0.008 0.109 0.109 0.104], Final Value = $3327142.53, Sharpe Ratio = 0.68

# %%
# List all Sharpe ratios generated from the simulation
sharpe_ratio_runs
# Out:
# array([0.67693584, 0.74368861, 0.71047646, ..., 0.71036324, 0.7352952 ,
#        0.7127702 ])

# %%
# Return the index of the maximum Sharpe ratio (Best simulation run)
print(sharpe_ratio_runs.argmax())
# Out:
# 318

# %%
# Return the maximum Sharpe ratio value
print(sharpe_ratio_runs.max().round(4))
# Out:
# 0.8214

# %%
# Obtain the portfolio weights that correspond to the maximum Sharpe ratio (Golden set of weights!)
print(weights_runs[sharpe_ratio_runs.argmax(), :])
# Out:
# [0.19370369 0.02302675 0.25033911 0.23385147 0.03638116 0.08407225
#  0.01549497 0.02736974 0.03471493 0.10104592]

# %%
# Return Sharpe ratio, volatility corresponding to the best weights allocation (maximum Sharpe ratio)
optimal_portfolio_return, optimal_volatility, optimal_sharpe_ratio, highest_final_value, optimal_return_on_investment = simulation_engine(weights_runs[sharpe_ratio_runs.argmax(), :], initial_investment)

print('Best Portfolio Metrics Based on {} Monte Carlo Simulation Runs:'.format(sim_runs))
print('  - Portfolio Expected Annual Return = {:.02f}%'.format(optimal_portfolio_return * 100))
print('  - Portfolio Standard Deviation (Volatility) = {:.02f}%'.format(optimal_volatility * 100))
print('  - Sharpe Ratio = {:.02f}'.format(optimal_sharpe_ratio))
print('  - Final Value = ${:.02f}'.format(highest_final_value))
print('  - Return on Investment = {:.02f}%'.format(optimal_return_on_investment))
# Out:
# Best Portfolio Metrics Based on 10000 Monte Carlo Simulation Runs:
#   - Portfolio Expected Annual Return = 18.09%
#   - Portfolio Standard Deviation (Volatility) = 18.37%
#   - Sharpe Ratio = 0.82
#   - Final Value = $3812980.47
#   - Return on Investment = 281.30%

# %%
# Create a DataFrame that contains volatility, return, and Sharpe ratio for all simualation runs
sim_out_df = pd.DataFrame({'Volatility': volatility_runs.tolist(), 'Portfolio_Return': expected_portfolio_returns_runs.tolist(), 'Sharpe_Ratio': sharpe_ratio_runs.tolist() })
sim_out_df
# Out:
#       Volatility  Portfolio_Return  Sharpe_Ratio
# 0       0.180947          0.152489      0.676936
# 1       0.175698          0.160665      0.743689
# 2       0.187430          0.163165      0.710476
# 3       0.177474          0.155207      0.705492
# 4       0.169952          0.161768      0.775326
# ...          ...               ...           ...
# 9995    0.183268          0.168655      0.756567
# 9996    0.183141          0.169565      0.762062
# 9997    0.171891          0.152105      0.710363
# 9998    0.179233          0.161789      0.735295
# 9999    0.192984          0.167553      0.712770
#
# [10000 rows x 3 columns]

# %%
# Let's highlight the point with the highest Sharpe ratio
import plotly.graph_objects as go

factor = 1.2

# Calculate the extended x-coordinate
extended_volatility = optimal_volatility * factor

# Calculate the slope of the line between (0, 0.03) and (optimal_volatility, optimal_portfolio_return)
slope = (optimal_portfolio_return - 0.03) / optimal_volatility

# Compute the extended y-coordinate using the line equation: y = slope * x + intercept
extended_return = slope * extended_volatility + 0.03

fig = px.scatter(sim_out_df,
                 x='Volatility',
                 y='Portfolio_Return',
                 color='Sharpe_Ratio',
                 size='Sharpe_Ratio',
                 size_max=10,  # Adjust this value as needed
                 hover_data=['Sharpe_Ratio'])
fig.add_trace(go.Scatter(x=[optimal_volatility],
                         y=[optimal_portfolio_return],
                         mode='markers',
                         name='Optimal Point',
                         marker=dict(
                         size=20,
                         color='red',
                         symbol='diamond'  # change to desired marker type
)
))
fig.add_trace(go.Scatter(x = [0], y = [0.03],
                         mode = 'markers',
                         name = 'Risk-free rate',
                         marker=dict(
                         size=20,
                         color='blue',
                         symbol='square'  # change to desired marker type
)
))
# Add the extended line trace
fig.add_trace(go.Scatter(
    x=[0, extended_volatility],
    y=[0.03, extended_return],
    mode='lines',
    name='Extended Line from Risk-Free to Beyond Optimal',
    line=dict(color='black', dash='dash')
))

fig.update_layout(coloraxis_colorbar=dict(y=0.7, dtick=5))
fig.update_layout({'plot_bgcolor': "white"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cee452a0-dcb4-4ba0-a5d9-525c34f3d351" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cee452a0-dcb4-4ba0-a5d9-525c34f3d351")) {                    Plotly.newPlot(                        "cee452a0-dcb4-4ba0-a5d9-525c34f3d351",                        [{"customdata":[[0.6769358377825291],[0.7436886101363093],[0.7104764643342989],[0.7054916724540705],[0.775325619494188],[0.7047382085020157],[0.7130580206705122],[0.7263332471279429],[0.7500312469960653],[0.7359516896087642],[0.7035124362478943],[0.7733201335857545],[0.7057070721235293],[0.7358264785044619],[0.7612095445878848],[0.6928030223349003],[0.7878575833148379],[0.8030383302796014],[0.701224727233935],[0.7030400592632069],[0.745468663936545],[0.7304948852215416],[0.7257777188764517],[0.7355322532363544],[0.6737707372671495],[0.7052304928650797],[0.75368336088126],[0.7595715642951036],[0.6954886806944347],[0.7531012955914782],[0.6911903706144605],[0.7103763567682629],[0.7525190010338575],[0.7557335074463187],[0.7441214137562073],[0.7247123803088078],[0.7916587856712224],[0.7540868959333499],[0.7848790118095902],[0.744124510682978],[0.6739293829257229],[0.7352326006688933],[0.698743202272925],[0.7304115467414495],[0.723407781012537],[0.7023711301898372],[0.720765171442717],[0.7214699092886141],[0.7289620653513258],[0.7315967770336911],[0.7078688872620321],[0.7941856666902807],[0.7338702918422342],[0.7462541308081707],[0.7020443335996386],[0.6945630755162752],[0.7048449419744979],[0.7243947783152751],[0.7138825850978214],[0.7004298301465692],[0.7249189314611056],[0.7194807314087341],[0.7595832933429195],[0.711887009362612],[0.7260842334379987],[0.7126465555173257],[0.7318702094453834],[0.7562138934617371],[0.7092741230964779],[0.7210692763091399],[0.7290585738176643],[0.7328069753060189],[0.7017827750892655],[0.6807664637639854],[0.7593357755151721],[0.7355723108858667],[0.7392486515364352],[0.5866814297009044],[0.7454598389817629],[0.7534004380727306],[0.7086521971459596],[0.7052128228229624],[0.7182195167226502],[0.6704732698083345],[0.7136622787806892],[0.7007213832132342],[0.6992618240309044],[0.7292445287565553],[0.680727992452943],[0.7353741486866363],[0.7434033073139958],[0.6645012833443752],[0.7266803239194071],[0.7321863631917171],[0.7399556302758524],[0.6969137959023418],[0.7599623549895307],[0.7086268578284407],[0.7616246307200046],[0.710378294237973],[0.6693073965554945],[0.6845510073777809],[0.6915613668266926],[0.7399218194803413],[0.7612308294266847],[0.7261863566160041],[0.7017631031782898],[0.7567472698664144],[0.7188200030141892],[0.7131074943976992],[0.7297955803225186],[0.7758343731748912],[0.7288059325930623],[0.7304639452598463],[0.7139759473564086],[0.7055619229746579],[0.720308345608182],[0.721478645854335],[0.6884522071158745],[0.7974904591876009],[0.7060194504111325],[0.7228586631243702],[0.749190309682869],[0.7091900199604956],[0.7525133559816686],[0.6177560873196805],[0.7314731818857593],[0.7126744813115985],[0.7323095887305586],[0.7035100312376444],[0.7253298415367146],[0.6770445681941595],[0.6912671531695367],[0.6461964725554037],[0.7128766359607815],[0.7520811714589011],[0.7056983609622948],[0.7218827170135923],[0.6457948001002193],[0.7338896574056415],[0.6914270411815515],[0.7322079381136497],[0.7564343746917929],[0.7158089244516098],[0.7426526118979041],[0.7553051710734059],[0.743637685592075],[0.7202454738386719],[0.7492459412980705],[0.7263446664149632],[0.6763114539240968],[0.753793576428669],[0.7180419974607816],[0.7242314068062335],[0.6806403706216613],[0.7585414005767391],[0.7492825599015035],[0.724636642977499],[0.7448768123247984],[0.708488464256639],[0.6952039723366702],[0.72965709576735],[0.7649536181600065],[0.7039101202429726 ...
